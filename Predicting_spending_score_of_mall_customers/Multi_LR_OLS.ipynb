# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Mall_Customers.csv')

# %%
df.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.rename(columns={"Spending Score (1-100)": "Spent Score"},inplace=True)

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spent Score
# 0             1    Male   19                  15           39
# 1             2    Male   21                  15           81
# 2             3  Female   20                  16            6
# 3             4  Female   23                  16           77
# 4             5  Female   31                  17           40
# ..          ...     ...  ...                 ...          ...
# 195         196  Female   35                 120           79
# 196         197  Female   45                 126           28
# 197         198    Male   32                 126           74
# 198         199    Male   32                 137           18
# 199         200    Male   30                 137           83
#
# [200 rows x 5 columns]

# %%
y = df['Spent Score']
X = df.drop(columns='Spent Score')

# %%
y
# Out:
# 0      39
# 1      81
# 2       6
# 3      77
# 4      40
#        ..
# 195    79
# 196    28
# 197    74
# 198    18
# 199    83
# Name: Spent Score, Length: 200, dtype: int64

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
X
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)
# 0             1    Male   19                  15
# 1             2    Male   21                  15
# 2             3  Female   20                  16
# 3             4  Female   23                  16
# 4             5  Female   31                  17
# ..          ...     ...  ...                 ...
# 195         196  Female   35                 120
# 196         197  Female   45                 126
# 197         198    Male   32                 126
# 198         199    Male   32                 137
# 199         200    Male   30                 137
#
# [200 rows x 4 columns]

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split
X_train ,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=45)

# %%
X_test
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)
# 45           46  Female   24                  39
# 72           73  Female   60                  50
# 40           41  Female   65                  38
# 58           59  Female   27                  46
# 25           26    Male   29                  28
# 13           14  Female   24                  20
# 153         154  Female   38                  78
# 80           81    Male   57                  54
# 3             4  Female   23                  16
# 44           45  Female   49                  39
# 134         135    Male   20                  73
# 149         150    Male   34                  78
# 173         174    Male   36                  87
# 33           34    Male   18                  33
# 62           63  Female   67                  47
# 182         183    Male   46                  98
# 112         113  Female   38                  64
# 129         130    Male   38                  71
# ...

# %%
y_train.shape
# Out:
# (160,)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
X_train['Gender'] = label_encoder.fit_transform(X_train['Gender'])
X_test['Gender'] = label_encoder.fit_transform(X_test['Gender'])

# %%
y_train.shape
# Out:
# (160,)

# %%
class MyLR:
  def __init__(self):
      self.coef=None
      self.intercept=None
      self.beta=None
  def fit(self,X_train,y_train):
      X_train = np.insert(X_train,0,1,axis=1)
      self.beta = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
      # print(beta)
      # self.intercept = beta[0]
      # self.coef = beta[1:]
      # print(self.intercept)
      # print(self.coef)
  def predict(self,X_test):
      X_test = np.insert(X_test,0,1,axis=1)
      res = np.dot(X_test,self.beta)
      return res

# %%
lr = MyLR()
lr.fit(X_train,y_train)

# %%
np.insert(X_train,0,1,axis=1).shape
# Out:
# (160, 5)

# %%
pred = lr.predict(X_test)
pred.shape
# Out:
# (40,)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,pred)
# Out:
# 21.31459066308504

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X_train,y_train)
PRED = LR.predict(X_test)
mean_absolute_error(y_test,PRED)
# Out:
# 21.314590663085323
