# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("advertising.csv")

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
new_df = scaler.fit_transform(df.drop(columns=('Sales')))
new_df = pd.DataFrame(new_df,columns=('a','b','c'))
new_df
# Out:
#             a         b         c
# 0    0.969852  0.981522  1.778945
# 1   -1.197376  1.082808  0.669579
# 2   -1.516155  1.528463  1.783549
# 3    0.052050  1.217855  1.286405
# 4    0.394182 -0.841614  1.281802
# ..        ...       ...       ...
# 195 -1.270941 -1.321031 -0.771217
# 196 -0.617035 -1.240003 -1.033598
# 197  0.349810 -0.942899 -1.111852
# 198  1.594565  1.265121  1.640850
# 199  0.993206 -0.990165 -1.005979
#
# [200 rows x 3 columns]

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
y = df['Sales'].values
X = new_df.values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X
# Out:
# array([[ 9.69852266e-01,  9.81522472e-01,  1.77894547e+00],
#        [-1.19737623e+00,  1.08280781e+00,  6.69578760e-01],
#        [-1.51615499e+00,  1.52846331e+00,  1.78354865e+00],
#        [ 5.20496822e-02,  1.21785493e+00,  1.28640506e+00],
#        [ 3.94182198e-01, -8.41613655e-01,  1.28180188e+00],
#        [-1.61540845e+00,  1.73103399e+00,  2.04592999e+00],
#        [-1.04557682e+00,  6.43904671e-01, -3.24708413e-01],
#        [-3.13436589e-01, -2.47406325e-01, -8.72486994e-01],
#        [-1.61657614e+00, -1.42906863e+00, -1.36042422e+00],
#        [ 6.16042873e-01, -1.39530685e+00, -4.30581584e-01],
#        [-9.45155670e-01, -1.17923146e+00, -2.92486143e-01],
#        [ 7.90028350e-01,  4.96973404e-02, -1.22232878e+00],
#        [-1.43908760e+00,  7.99208859e-01,  1.62704048e+00],
#        [-5.78501712e-01, -1.05768905e+00, -1.07502697e+00],
#        [ 6.66253447e-01,  6.50657027e-01,  7.11007392e-01],
#        [ 5.64664612e-01,  1.65000572e+00,  1.02862691e+00],
# ...

# %%
import random
class MGD:
    def __init__(self,epochs,lr,batch_size):
        self.coef = None
        self.intercept = None
        self.epochs = epochs
        self.lr = lr
        self.batch_size = batch_size
    def fit(self,X_train,y_train):
      self.coef = np.ones(X_train.shape[1])
      self.intercept = 0
        # print(self.coef.shape)
      for i in range(self.epochs):
       for j in range(int(X_train.shape[0]/self.batch_size)):   
         batch = random.sample(range(X_train.shape[0]),self.batch_size)
         y_hat = np.dot(X_train[batch],self.coef)+self.intercept
         # print(y_hat)   
         slope_i = -2*(np.mean(y_train[batch]-y_hat)) 
         slope_c = -2*(np.dot((y_train[batch]-y_hat),X_train[batch]))/self.batch_size   
         # print(slope_c.shape)
         self.coef = self.coef - (self.lr*slope_c)    #without scaling this line raises an error
         self.intercept = self.intercept - (self.lr*slope_i)       
      print(self.intercept,self.coef)
    def predict(self,X_test):
        return np.dot(X_test,self.coef) + self.intercept

# %%
mgd = MGD(50,0.01,10)
mgd.fit(X_train,y_train)
pred = mgd.predict(X_test)
# Out:
# 15.199891825822009 [4.66214135 1.50753774 0.16800996]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,pred)
# Out:
# 0.9083463197556083

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd = SGDRegressor(learning_rate='constant',eta0=0.1)

# %%
batch_size = 10

for i in range(50):

  idx = random.sample(range(X_train.shape[0]),batch_size)
  sgd.partial_fit(X_train[idx],y_train[idx])
sgd.predict(X_test)
print(sgd.intercept_,sgd.coef_)
# Out:
# [15.37148604] [4.38858037 1.40753375 0.195208  ]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,sgd.predict(X_test))
# Out:
# 0.9006897529816357
